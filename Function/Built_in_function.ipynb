# %%
mean = sum(prices)/len(prices)
print(mean)
# Out:
# 350.0

# %%
prices = [200,300,400,500]
sum(prices)
print(sum(prices))
# Out:
# 1400

# %%
max(prices)
print(max(prices))
# Out:
# 500

# %%
min(prices)
print(min(prices))
# Out:
# 200
