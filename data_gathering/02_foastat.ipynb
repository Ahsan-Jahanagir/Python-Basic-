# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.0
# /var/folders/dp/s3___bhn2dd4l3b9g3q1whnc0000gn/T/ipykernel_1773/1804728916.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import faostat

# %%
faostat.list_datasets()
# Out:
# [('code',
#   'label',
#   'date_update',
#   'note_update',
#   'release_current',
#   'state_current',
#   'year_current',
#   'release_next',
#   'state_next',
#   'year_next'),
#  ('QCL',
#   'Crops and livestock products',
#   '2025-06-11',
#   'minor revision',
#   '2024-12-20 / 2025-06-11',
#   'final',
#   '2023',
#   '2025-12',
#   'final',
#   '2024'),
#  ('QI',
#   'Production Indices',
#   '2025-02-03',
#   '',
#   '2025-02-03',
#   'final',
#   '2023',
#   '2025-12',
#   'final',
#   '2024'),
#  ('QV',
#   'Value of Agricultural Production',
#   '2025-02-03',
#   '',
#   '2025-02-03',
#   'final',
#   '2023',
#   '2025-12',
#   'final',
#   '2024'),
#  ('FS',
#   'Suite of Food Security Indicators',
#   '2025-07-28',
#   '',
#   '2025-07-28',
#   'final',
#   '2024',
#   '2026-07',
#   'final',
#   '2025'),
#  ('FBS',
#   'Food Balances (2010-)',
#   '2025-10-28',
#   '',
#   '2025-10-28',
#   'final',
#   '2023',
#   '2026-10',
#   'final',
#   '2024'),
#  ('SCL',
# ...

# %% [markdown]
# what is at 0 index

# %%
data = faostat.list_datasets()
data[0]
# Out:
# ('code',
#  'label',
#  'date_update',
#  'note_update',
#  'release_current',
#  'state_current',
#  'year_current',
#  'release_next',
#  'state_next',
#  'year_next')

# %% [markdown]
# Range

# %%
data = faostat.list_datasets()
data[1:4]
# Out:
# [('QCL',
#   'Crops and livestock products',
#   '2025-06-11',
#   'minor revision',
#   '2024-12-20 / 2025-06-11',
#   'final',
#   '2023',
#   '2025-12',
#   'final',
#   '2024'),
#  ('QI',
#   'Production Indices',
#   '2025-02-03',
#   '',
#   '2025-02-03',
#   'final',
#   '2023',
#   '2025-12',
#   'final',
#   '2024'),
#  ('QV',
#   'Value of Agricultural Production',
#   '2025-02-03',
#   '',
#   '2025-02-03',
#   'final',
#   '2023',
#   '2025-12',
#   'final',
#   '2024')]

# %% [markdown]
# Data Frame

# %%
faostat.list_datasets_df()
# Out:
#    code                              label date_update     note_update  \
# 0   QCL       Crops and livestock products  2025-06-11  minor revision
# 1    QI                 Production Indices  2025-02-03
# 2    QV   Value of Agricultural Production  2025-02-03
# 3    FS  Suite of Food Security Indicators  2025-07-28
# 4   FBS              Food Balances (2010-)  2025-10-28
# ..  ...                                ...         ...             ...
# 63   FA           Food Aid Shipments (WFP)  2016-12-22
# 64   RM                          Machinery  2021-12-03  minor revision
# 65   RY                  Machinery Archive  2021-12-03  minor revision
# 66   RA                Fertilizers archive  2020-09-08  minor revision
# 67   PA       Producer Prices (old series)  1991-12-31
#
#             release_current state_current year_current release_next  \
# 0   2024-12-20 / 2025-06-11         final         2023      2025-12
# 1                2025-02-03         final         2023      2025-12
# ...

# %% [markdown]
# save as csv

# %%
df = faostat.list_datasets_df()
df.to_csv('datasets/faostat.csv',index=False)

# %% [markdown]
# data for special group

# %%
y = faostat.get_par_df('Qcl', 'area')
y
# Out:
#                                                  label   code aggregate_type
# 0                                          Afghanistan      2              0
# 1                                              Albania      3              0
# 2                                              Algeria      4              0
# 3                                               Angola      7              0
# 4                                  Antigua and Barbuda      8              0
# ..                                                 ...    ...            ...
# 274     Small Island Developing States (SIDS) > (List)  5803>              >
# 275  Low Income Food Deficit Countries (LIFDCs) + (...   5815              +
# 276  Low Income Food Deficit Countries (LIFDCs) > (...  5815>              >
# 277  Net Food Importing Developing Countries (NFIDC...   5817              +
# 278  Net Food Importing Developing Countries (NFIDC...  5817>              >
#
# [279 rows x 3 columns]

# %% [markdown]
# Download a subset of data based on parameters, as a list of tuples

# %%
mypars = {'element':[2312, 2313], 'item':'221'}
data = faostat.get_data('QCL', pars=mypars)
data[40:44]
# Out:
# [('QCL',
#   'Crops and livestock products',
#   '2',
#   'Afghanistan',
#   '5312',
#   'Area harvested',
#   '221',
#   'Almonds, in shell',
#   '2000',
#   '2000',
#   'ha',
#   '7000'),
#  ('QCL',
#   'Crops and livestock products',
#   '2',
#   'Afghanistan',
#   '5312',
#   'Area harvested',
#   '221',
#   'Almonds, in shell',
#   '2001',
#   '2001',
#   'ha',
#   '9000'),
#  ('QCL',
#   'Crops and livestock products',
#   '2',
#   'Afghanistan',
#   '5312',
#   'Area harvested',
#   '221',
#   'Almonds, in shell',
#   '2002',
#   '2002',
#   'ha',
#   '5500'),
#  ('QCL',
#   'Crops and livestock products',
#   '2',
#   'Afghanistan',
#   '5312',
#   'Area harvested',
#   '221',
#   'Almonds, in shell',
#   '2003',
#   '2003',
#   'ha',
#   '5700')]

# %% [markdown]
# get data in data frame

# %%
df = faostat.get_data_df('QCL', pars=mypars)
df
# Out:
#      Domain Code                        Domain Area Code  \
# 0            QCL  Crops and livestock products         2
# 1            QCL  Crops and livestock products         2
# 2            QCL  Crops and livestock products         2
# 3            QCL  Crops and livestock products         2
# 4            QCL  Crops and livestock products         2
# ...          ...                           ...       ...
# 4241         QCL  Crops and livestock products      5817
# 4242         QCL  Crops and livestock products      5817
# 4243         QCL  Crops and livestock products      5817
# 4244         QCL  Crops and livestock products      5817
# 4245         QCL  Crops and livestock products      5817
#
#                                                   Area Element Code  \
# 0                                          Afghanistan         5312
# 1                                          Afghanistan         5312
# 2                                          Afghanistan         5312
# ...

# %% [markdown]
# save to csv file

# %%
df.to_csv('./datasets/faostat_data_cr.csv', index=False)

# %% [markdown]
# colums in data

# %%
df.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code', 'Area', 'Element Code', 'Element',
#        'Item Code', 'Item', 'Year Code', 'Year', 'Unit', 'Value'],
#       dtype='object')

# %% [markdown]
# Call specific data

# %%
df = df[["Domain", "Area", "Element", "Item", "Year", "Unit", "Value"]]
df
# Out:
#                             Domain  \
# 0     Crops and livestock products
# 1     Crops and livestock products
# 2     Crops and livestock products
# 3     Crops and livestock products
# 4     Crops and livestock products
# ...                            ...
# 4241  Crops and livestock products
# 4242  Crops and livestock products
# 4243  Crops and livestock products
# 4244  Crops and livestock products
# 4245  Crops and livestock products
#
#                                                   Area         Element  \
# 0                                          Afghanistan  Area harvested
# 1                                          Afghanistan  Area harvested
# 2                                          Afghanistan  Area harvested
# 3                                          Afghanistan  Area harvested
# 4                                          Afghanistan  Area harvested
# ...                                                ...             ...
# ...

# %% [markdown]
# save to xlsx

# %%
df.to_csv('./datasets/faostat.crr.csv', index=False)
