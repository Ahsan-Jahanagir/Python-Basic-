# %%
list = ["Ahsan", "khan", "ali", "subhan"]
for name in list:
    print(f"{name} have white dress")
# Out:
# Ahsan have white dress
# khan have white dress
# ali have white dress
# subhan have white dress

# %%
list = ["biryani", "Aloo", "palak","chicken"]
for dish in list:
    print(f"{dish} is available in the menu")
# Out:
# biryani is available in the menu
# Aloo is available in the menu
# palak is available in the menu
# chicken is available in the menu

# %%
cup_of_chye = 9
while cup_of_chye < 3:
    cup_of_chye += 1
    print("i need more chye")
    
print("i am full now")
# Out:
# i am full now

# %%
cup_of_chye = 3
while cup_of_chye < 5:
    cup_of_chye += 1 
    print("i want more chye")
    if cup_of_chye == 3:
        print("too much chye stopping now")
        break
    print(f"chye {cup_of_chye} served")
# Out:
# i want more chye
# chye 4 served
# i want more chye
# chye 5 served

# %%
cup_of_chye = 2
while cup_of_chye < 5:
    cup_of_chye += 1
    print ( " i want more chye")
    if cup_of_chye == 3:
        print("too mucch chye stop plz")
        break 
    print(f"chye {cup_of_chye} is served")
# Out:
#  i want more chye
# too mucch chye stop plz

# %%
cup_of_chye = 2
while cup_of_chye < 5:
    cup_of_chye += 1
    print ( " i want more chye")
    if cup_of_chye == 3:
        print("too mucch chye stop plz")
        continue 
    print(f"chye {cup_of_chye} should be served")
# Out:
#  i want more chye
# too mucch chye stop plz
#  i want more chye
# chye 4 should be served
#  i want more chye
# chye 5 should be served

# %% [markdown]
# # range funtion in loop  --> -->

# %%
for cup in range( 1,20,5):
    print(f"chaie is ready, chai cup {cup} served")
# Out:
# chaie is ready, chai cup 1 served
# chaie is ready, chai cup 6 served
# chaie is ready, chai cup 11 served
# chaie is ready, chai cup 16 served

# %%
count = 0
while True:
    count += 1
    print(f" iteration {count}")
    if count == 3:
        print("Break infinite loop now")
        break
# Out:
#  iteration 1
#  iteration 2
#  iteration 3
# Break infinite loop now

# %%
while True:
    print("hello world")
    if count == 3:
        break
# Out:
# hello world

# %% [markdown]
# infinite loop

# %%
while True:
    print("hello world")
    break
# Out:
# hello world

# %%
while True:
    print("hello world")
    continue
# Out:
# hello world

# %%
while True:
    print("hello world")
    pass

# %%
count = 0
while True:
    count += 1
    print("it will run forever")
    if count == 6:
        print("stop")
        break
# Out:
# it will run forever
# it will run forever
# it will run forever
# it will run forever
# it will run forever
# it will run forever
# stop

# %% [markdown]
# continue and pass in loop

# %%
cup_of_chaye = 0
while cup_of_chaye <5:
    cup_of_chaye += 1 
    print("i want more chaye")
    if cup_of_chaye == 3:
        print("too much chye stopped now")
        continue
    print(f"i had {cup_of_chaye} cups of chaye")
# Out:
# i want more chaye
# i had 1 cups of chaye
# i want more chaye
# i had 2 cups of chaye
# i want more chaye
# too much chye stopped now
# i want more chaye
# i had 4 cups of chaye
# i want more chaye
# i had 5 cups of chaye

# %%
cup_of_chaye = 0
while cup_of_chaye <5:
    cup_of_chaye += 1 
    print("i want more chaye")
    if cup_of_chaye == 3:
        print("too much chye stopped now")
        pass
    print(f"i had {cup_of_chaye} cups of chaye")
# Out:
# i want more chaye
# i had 1 cups of chaye
# i want more chaye
# i had 2 cups of chaye
# i want more chaye
# too much chye stopped now
# i had 3 cups of chaye
# i want more chaye
# i had 4 cups of chaye
# i want more chaye
# i had 5 cups of chaye

# %% [markdown]
# try, exampt, finally

# %%
try:
    print("Hello Ahsan")
    print(1/0)
except ZeroDivisionError:
    print("zero divison error") 
finally:
    print("this will execute no matter what")
# Out:
# Hello Ahsan
# zero divison error
# this will execute no matter what
