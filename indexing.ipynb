# %%
 matrix = [
     [1,2,3],
     [4,5,6],
     [7,8,9] 
 ]
 print(matrix[2][2])
# Out:
# 9

# %%
name = "codanics"
length = len(name)
name[-2:-1]
print(name)
# Out:
# codanics

# %%
name = "codanics"
print(name[-5:-1])
# Out:
# anic
