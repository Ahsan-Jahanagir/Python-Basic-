# %% [markdown]
# #sequence
# #Range

# %%
# Out:
# ahsan

# %%
number_a = range(1,10,2)
print(list(number_a))
# Out:
# [1, 3, 5, 7, 9]

# %%
text = ("pythonekachilla")
print[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 text = ("pythonekachilla")
# ----> 2 print[0]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable
